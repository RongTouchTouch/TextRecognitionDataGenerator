# %%
import os
import time
import math
import random
import shutil
import contextlib
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence
import torch.utils.data as data
import torchvision.transforms as transforms

from utils.converter import LabelConverter, IndexConverter
from datasets.dataset import InMemoryDigitsDataset, DigitsDataset, collate_train, collate_dev, inmemory_train, inmemory_dev
from generate import gen_text_img

import arguments
from models.densenet_ import DenseNet


def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()

    model.train()

    end = time.time()
    
    for i, sample in enumerate(train_loader):
        data_time.update(time.time() - end)
        
        images = sample.images
        images = images.to(device)
        targets = sample.targets
        targets = targets.to(device)
        target_lengths = sample.target_lengths

        optimizer.zero_grad()

        log_probs = model(images)
        input_lengths = torch.full((images.size(0),),log_probs.size(0), dtype=torch.int32, device=device)

        loss = criterion(log_probs, targets, input_lengths, target_lengths)
        losses.update(loss.item())
        loss.backward()

        optimizer.step()
        
        batch_time.update(time.time() - end)
        end = time.time()

        if (i+1) % args.print_freq == 0 or i == 0 or (i+1) == len(train_loader):
            print('>> Train: [{0}][{1}/{2}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})'.format(
                   epoch+1, i+1, len(train_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses))

    return losses.avg


def validate(dev_loader, model, epoch, converter):
    batch_time = AverageMeter()
    accuracy = AverageMeter()

    # switch to evaluate mode
    model.eval()

    num_correct = 0
    num_verified = 0
    end = time.time()
    
    for i, sample in enumerate(dev_loader):
        images = sample.images
        images = images.to(device)
        targets = sample.targets

        optimizer.zero_grad()

        log_probs = model(images)
        preds = converter.best_path_decode(log_probs, strings=False)
        
        batch_time.update(time.time() - end)
        end = time.time()

        for i in range(len(targets)):
            num_verified += len(targets[i])
        for pred, target in zip(preds, targets):
            if(pred == target):
                num_correct += 1
        accuracy.update(num_correct / num_verified) # character
        for i in range(len(preds)):
            pred = converter.best_path_decode(log_probs, strings=True)[i].decode('utf-8')
            print('pred: {}'.format(pred))
            
        if (i+1) % args.print_freq == 0 or i == 0 or (i+1) == len(dev_loader):
            print('>> Val: [{0}][{1}/{2}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Accu {accuracy.val:.3f}'.format(
                   epoch+1, i+1, len(dev_loader), batch_time=batch_time, accuracy=accuracy))

    return accuracy.val

def save_checkpoint(state, is_best, directory):
    filename = os.path.join(directory, '{}_epoch_{}.pth.tar'.format(state['arch'], state['epoch']))
    with contextlib.suppress(FileNotFoundError):
        os.remove(filename)
    torch.save(state, filename)
    if is_best:
        print('>>>> save best model at epoch: {}'.format(state['epoch']))
        filename_best = os.path.join(directory, '{}_best.pth.tar'.format(state['arch']))
        with contextlib.suppress(FileNotFoundError):
            os.remove(filename_best)
        shutil.copyfile(filename, filename_best)


class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
import sys
# alphabet/alphabet_decode_5990.txt
sys.argv = ['main.py','--dataset-root','alphabet','--arch','densenet121','--alphabet','alphabet/alphabet_decode_5990.txt',
            '--lr','5e-5','--max-epoch','20','--optimizer','rmsprop','--gpu-id','-1']
args = arguments.parse_args()

# %%
device = torch.device("cpu")
    
if os.path.isfile(args.alphabet):
    alphabet = ''
    with open(args.alphabet, mode='r', encoding='utf-8') as f:
        for line in f.readlines():
            alphabet += line.strip()
    args.alphabet = alphabet

num = 100
dev_num = num
use_file = 1
text = "嘤嘤嘤"
text_length = 10
font_size = -1
font_id = -1
space_width = 1
text_color = '#282828'
thread_count = 8
channel = 3

random_skew = True
skew_angle = 2
random_blur = True
blur = 0.5

orientation = 0
distorsion = -1
distorsion_orientation = 2
background = 1

random_process = True
noise = 20
erode = 2
dilate = 2
incline = 10

transform = transforms.Compose([
    transforms.Resize((32, 280)),
    transforms.ToTensor(),
])

model = DenseNet(num_classes=len(args.alphabet) + 1)
if args.pretrained:
    model_path = 'pretrained/new_prarams2.pth'
    checkpoint = torch.load(model_path,map_location = 'cpu')
    model.load_state_dict(checkpoint)

criterion = nn.CTCLoss()
# critierion = nn.CrossEntropyLoss()
criterion = criterion.to(device)

optimizer = optim.SGD(params=model.parameters(),lr=args.lr,
                      momentum=args.momentum, weight_decay=args.weight_decay)

label_converter = LabelConverter(args.alphabet, ignore_case=False)

is_best = False
best_accuracy = 0.0
accuracy = 0.0
start_epoch = 0

acc = []

round = 5
for i in range(round):
    text_meta, text_img = gen_text_img(num, use_file, text, text_length, font_size, font_id, space_width,
                                       background, text_color,
                                       orientation, blur, random_blur, distorsion, distorsion_orientation,
                                       skew_angle, random_skew,
                                       random_process, noise, erode, dilate, incline,
                                                                thread_count)
    dev_meta, dev_img = text_meta, text_img

    index_converter = IndexConverter(args.alphabet, ignore_case=True)

    train_dataset = InMemoryDigitsDataset(mode='train', text=text_meta, img=text_img, total=num,
                                         transform=transform, converter = index_converter)
    dev_dataset = InMemoryDigitsDataset(mode='dev', text=dev_meta, img=dev_img, total=num,
                                       transform=transform, converter = index_converter)

    train_loader = data.DataLoader(dataset=train_dataset,batch_size=args.batch_size, num_workers=4, shuffle=True,
                                   collate_fn=collate_train, pin_memory=True)
    dev_loader = data.DataLoader(dataset=dev_dataset,batch_size=args.batch_size, num_workers=4, shuffle=False,
                                 collate_fn=collate_dev, pin_memory=False)

    for epoch in range(start_epoch, args.max_epoch):
        loss = train(train_loader, model, criterion, optimizer, epoch)

        if (epoch + 1) % args.validate_interval == 0:
            with torch.no_grad():
                accuracy = validate(dev_loader, model, epoch, label_converter)

        is_best = accuracy > 0.0 and accuracy >= best_accuracy
        best_accuracy = max(accuracy, best_accuracy)
        acc.append(format(accuracy))
        print('>>>> Accuracy: {}'.format(accuracy))

        if (epoch + 1) % args.save_interval == 0:
            save_checkpoint({
                'arch': args.arch,
                'epoch': epoch + 1,
                'state_dict': model.state_dict(),
                'best_accuracy': best_accuracy,


                'optimizer' : optimizer.state_dict(),
            }, is_best, args.directory)
                
        if best_accuracy == 1:
            break
# Out:
# >> Train: [1][1/2]	Time 5.818 (5.818)	Data 0.216 (0.216)	Loss 13.9981 (13.9981)
# >> Train: [1][2/2]	Time 3.120 (4.469)	Data 0.001 (0.109)	Loss 14.0053 (14.0017)
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# >>>> Accuracy: 0.0
# >> Train: [2][1/2]	Time 5.822 (5.822)	Data 0.247 (0.247)	Loss 13.8829 (13.8829)
# >> Train: [2][2/2]	Time 3.161 (4.492)	Data 0.001 (0.124)	Loss 13.8184 (13.8507)
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred: 四四四
# pred:
# pred: 三四三三三四四
# pred: 四四四
# pred: 三四四三
# pred: 四
# pred: 三
# pred: 四四四四七
# pred:
# pred: 三四
# pred: 四七三
# pred: 六
# pred: 四四四三
# pred: 四四三三四四
# pred: 四四三
# pred: 四四四
# pred: 七
# pred: 四
# pred: 四七四
# pred:
# pred: 四七六
# pred: 三四四
# pred:
# pred: 四四
# pred:
# pred: 七
# pred: 四
# pred: 四四七
# pred:
# pred: 三
# pred: 四三三
# pred: 三
# pred: 四
# >>>> Accuracy: 0.0
# >> Train: [16][1/2]	Time 5.607 (5.607)	Data 0.230 (0.230)	Loss 9.0716 (9.0716)
# >> Train: [16][2/2]	Time 2.924 (4.265)	Data 0.001 (0.115)	Loss 9.0723 (9.0719)
# pred: 四
# pred: 七
# pred: 三
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred: 四
# pred: 四
# pred:
# pred:
# pred:
# pred: 四四
# pred: 四三三四四
# pred: 七一
# pred: 四四
# pred: 四四
# pred: 六
# pred:
# pred: 四四七一
# pred: 三
# pred: 三三四三四
# pred:
# pred: 四
# pred: 三
# pred: 四七
# pred: 七三
# pred:
# pred:
# pred:
# pred: 七
# pred: 四
# pred: 七
# pred: 四四
# pred: 六四三三
# pred: 四四
# pred: 四七
# pred: 四四六
# pred: 四
# pred:
# pred: 四
# pred: 六四
# pred:
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 三六三四三
# pred: 四
# pred: 三
# pred: 四四
# pred: 四
# pred: 七
# pred:
# pred: 四
# pred: 七
# pred: 六三
# pred: 四
# pred:
# pred: 六
# pred: 四四四
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三四三三四
# pred: 四
# pred: 三四三
# pred: 四
# pred: 三
# pred: 四四四四七
# pred:
# pred: 三四
# pred: 四三
# pred: 六
# pred: 四四四
# pred: 四四四五四
# pred: 三
# pred: 四四四
# pred: 七
# pred:
# pred: 七
# pred:
# pred: 四六
# pred: 四四
# pred:
# pred:
# pred:
# pred: 七
# pred: 四
# pred: 四七
# pred:
# pred: 三
# pred: 四三
# pred:
# pred: 四
# >>>> Accuracy: 0.0
# >> Train: [17][1/2]	Time 5.731 (5.731)	Data 0.212 (0.212)	Loss 9.1063 (9.1063)
# >> Train: [17][2/2]	Time 2.944 (4.338)	Data 0.000 (0.106)	Loss 9.0716 (9.0889)
# pred: 四
# pred: 七
# pred: 三
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred: 四
# pred: 四
# pred:
# pred:
# pred:
# pred: 四
# pred: 四三三四
# pred: 七一
# pred: 四四
# pred: 四四
# pred: 六
# pred:
# pred: 四一
# pred:
# pred: 三三四三四
# pred:
# pred: 四
# pred: 三
# pred: 四七
# pred: 七三
# pred:
# pred:
# pred:
# pred: 七
# pred: 四
# pred:
# pred: 四
# pred: 六三三
# pred: 四
# pred:
# pred: 四六
# pred: 四
# pred:
# pred:
# pred: 六四
# pred:
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 三六三
# pred: 四
# pred: 一
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 六三
# pred:
# pred:
# pred:
# pred: 四四四
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三四三三
# pred: 四
# pred: 三四三
# pred:
# pred: 三
# pred: 四四四四七
# pred:
# pred: 三
# pred: 四三
# pred: 六
# pred: 四四
# pred: 四四五三
# pred:
# pred: 四四四
# pred: 七
# pred:
# pred: 七
# pred:
# pred: 四六
# pred: 四四
# pred:
# pred:
# pred:
# pred: 七
# pred:
# pred: 四七
# pred:
# pred: 三
# pred: 四三
# pred:
# pred: 四
# >>>> Accuracy: 0.0
# >> Train: [18][1/2]	Time 5.687 (5.687)	Data 0.253 (0.253)	Loss 9.0671 (9.0671)
# >> Train: [18][2/2]	Time 3.078 (4.382)	Data 0.003 (0.128)	Loss 9.0897 (9.0784)
# pred: 四
# pred: 七
# pred: 三
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred: 四
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred: 四三四
# pred: 七一
# pred: 四四
# pred: 四
# pred: 六
# pred:
# pred: 四一
# pred:
# pred: 三三四三四
# pred:
# pred:
# pred: 三
# pred: 四
# pred: 七三
# pred:
# pred:
# pred:
# pred: 七
# pred: 四
# pred:
# pred: 四
# pred: 六三三
# pred: 四
# pred:
# pred: 六
# pred: 四
# pred:
# pred:
# pred: 六四
# pred:
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 三六三
# pred: 四
# pred: 一
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 六三
# pred:
# pred:
# pred:
# pred: 四四
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三四三三
# pred: 四
# pred: 三四三
# pred:
# pred: 三
# pred: 四四四七
# pred:
# pred: 三
# pred: 三
# pred: 六
# pred: 四四
# pred: 四四五
# pred:
# pred: 四四四
# pred: 七
# pred:
# pred:
# pred:
# pred: 四六
# pred: 四四
# pred:
# pred:
# pred:
# pred: 七
# pred:
# pred: 四七
# pred:
# pred: 三
# pred: 四三
# pred:
# pred: 四
# >>>> Accuracy: 0.0
# >> Train: [19][1/2]	Time 5.634 (5.634)	Data 0.250 (0.250)	Loss 9.0484 (9.0484)
# >> Train: [19][2/2]	Time 2.998 (4.316)	Data 0.004 (0.127)	Loss 9.0469 (9.0477)
# pred: 四
# pred: 七
# pred: 三
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred: 四
# pred: 四
# pred:
# pred:
# pred:
# pred: 一
# pred: 四三四
# pred: 七一
# pred: 四四
# pred: 四
# pred: 六
# pred:
# pred: 四一
# pred:
# pred: 三三四三四
# pred:
# pred: 四
# pred: 三
# pred: 四四
# pred: 七三
# pred:
# pred:
# pred:
# pred: 七
# pred: 四
# pred:
# pred: 四
# pred: 六三三
# pred: 四
# pred:
# pred: 六
# pred: 四
# pred:
# pred:
# pred: 六四
# pred:
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 三六三
# pred: 四
# pred: 一
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 六三
# pred:
# pred:
# pred: 六
# pred: 四四
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三四三三
# pred: 四
# pred: 三三
# pred:
# pred: 三
# pred: 四四四七
# pred:
# pred: 三
# pred: 三
# pred: 六
# pred: 四四
# pred: 四四五
# pred:
# pred: 四四
# pred: 七
# pred:
# pred:
# pred:
# pred: 四六
# pred: 三四
# pred:
# pred:
# pred:
# pred: 七
# pred:
# pred: 四七
# pred:
# pred: 三
# pred: 四三
# pred:
# pred: 四
# >>>> Accuracy: 0.0
# >> Train: [20][1/2]	Time 5.500 (5.500)	Data 0.228 (0.228)	Loss 9.0259 (9.0259)
# >> Train: [20][2/2]	Time 2.955 (4.227)	Data 0.002 (0.115)	Loss 8.9573 (8.9916)
# pred: 四
# pred: 七
# pred: 三
# pred:
# pred:
# pred: 七
# pred:
# pred:
# pred: 四
# pred: 四
# pred:
# pred:
# pred:
# pred: 一
# pred: 四三四
# pred: 七一
# pred: 四四
# pred: 四
# pred: 六
# pred:
# pred: 四四一
# pred:
# pred: 三三四三四
# pred:
# pred: 四
# pred: 三
# pred: 四四
# pred: 七三
# pred:
# pred:
# pred:
# pred: 七
# pred: 四
# pred: 四
# pred: 四
# pred: 六六三
# pred: 四
# pred:
# pred: 六
# pred: 四
# pred:
# pred:
# pred: 六四
# pred: 四
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 三六三
# pred: 四
# pred: 一
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 六三
# pred:
# pred:
# pred: 六
# pred: 四三
# pred:
# pred: 七
# pred:
# pred:
# pred:
# pred: 四
# pred:
# pred: 三四三三
# pred: 四
# pred: 三三
# pred:
# pred: 三
# pred: 四四四七
# pred:
# pred: 三
# pred: 三
# pred: 六
# pred: 四四
# pred: 四一五
# pred:
# pred: 四四
# pred: 七
# pred:
# pred: 七
# pred:
# pred: 四六
# pred: 三四
# pred:
# pred:
# pred:
# pred: 七
# pred:
# pred: 四
# pred:
# pred: 三
# pred: 四三
# pred:
# pred: 四
# >>>> Accuracy: 0.0
# >> Train: [1][1/2]	Time 5.632 (5.632)	Data 0.222 (0.222)	Loss 8.9200 (8.9200)
# >> Train: [1][2/2]	Time 3.199 (4.416)	Data 0.001 (0.112)	Loss 8.9588 (8.9394)
# pred: 四
# pred: 四四
# pred:
# pred:
# pred: 七
# pred:
# pred: 四三六
# pred: 四
# pred:
# pred:
# pred: 七四四三
# pred: 四六
# pred: 四
# pred: 四
# pred:
# pred:
# pred: 四三四
# pred: 三四
# pred: 三
# pred:
# pred:
# pred: 三
# pred: 四
# pred:
# pred: 七
# pred: 三六
# pred:
# pred:
# pred: 六
# pred:
# pred:
# pred: 四
# pred:
# pred: 三三三
# pred: 四
# pred:
# pred: 四
# pred: 四三
# pred: 四
# pred: 四
# pred: 四
# pred: 四三二
# pred: 三四
# pred: 四
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred: 四
# pred: 四四
# pred: 六
# pred: 四七三
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三
# pred: 三
# pred: 四
# pred: 四
# pred: 三三三
# pred:
# pred: 六四四
# pred: 四
# pred: 一三
# pred:
# pred:
# pred:
# pred:
# pred:
# pred:
# pred: 七
# pred: 四四四三
# pred: 四
# pred:
# pred: 三
# pred:
# pred: 四四
# pred: 一三四
# pred:
# pred: 四三
# pred:
# pred: 四七
# pred: 一
# pred: 四三三三三
# pred: 四四四七
# pred:
# pred: 四
# pred:
# pred:
# pred: 四六
# pred: 六
# >>>> Accuracy: 0.0
# >> Train: [2][1/2]	Time 5.547 (5.547)	Data 0.245 (0.245)	Loss 8.9187 (8.9187)
# >> Train: [2][2/2]	Time 3.126 (4.337)	Data 0.001 (0.123)	Loss 8.9218 (8.9202)
# pred: 四
# pred: 四四
# pred:
# pred: 一
# pred: 七
# pred:
# pred: 四三六
# pred: 四
# pred:
# pred:
# pred: 四四四一三
# pred: 四六
# pred: 四
# pred: 四
# pred:
# pred: 一
# pred: 四三四
# pred: 三四
# pred: 三
# pred: 一
# pred:
# pred: 三
# pred: 四
# pred:
# pred: 七
# pred: 三六
# pred:
# pred:
# pred: 六
# pred:
# pred:
# pred: 四
# pred:
# pred: 三三三
# pred: 四
# pred:
# pred: 四
# pred: 四三
# pred: 四
# pred: 四
# pred: 四
# pred: 四三二
# pred: 三四
# pred: 四
# pred: 四
# pred: 四四四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred: 六
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred: 四
# pred: 四四
# pred: 六
# pred: 四七三
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三
# pred: 三三
# pred: 四
# pred: 四
# pred: 三三三
# pred:
# pred: 六四四
# pred: 四
# pred: 一三
# pred:
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred: 四
# pred: 四四四三
# pred: 四
# pred:
# pred: 三
# pred:
# pred: 四四
# pred: 三四
# pred:
# pred: 四三
# pred:
# pred: 四七
# pred: 一一
# pred: 四三三三三
# pred: 四四四七
# pred:
# pred: 四
# pred:
# pred:
# pred: 四六
# pred: 六
# >>>> Accuracy: 0.0
# >> Train: [3][1/2]	Time 5.854 (5.854)	Data 0.239 (0.239)	Loss 8.9188 (8.9188)
# >> Train: [3][2/2]	Time 2.962 (4.408)	Data 0.001 (0.120)	Loss 8.9111 (8.9150)
# pred: 四
# pred: 三四
# pred:
# pred: 一
# pred: 七
# pred:
# pred: 四三六
# pred: 四
# pred:
# pred:
# pred: 四四四一三
# pred: 四六
# pred: 四
# pred: 四四
# pred:
# pred: 一
# pred: 四四
# pred: 三四
# pred: 三
# pred: 一
# pred:
# pred: 三
# pred: 四
# pred:
# pred: 七
# pred: 三六
# pred:
# pred:
# pred: 六
# pred:
# pred:
# pred: 四
# pred: 二
# pred: 三三三
# pred: 四
# pred:
# pred: 四
# pred: 四三六
# pred: 四
# pred: 四六
# pred: 四
# pred: 四三二
# pred: 三四
# pred: 四四
# pred: 四
# pred: 四四四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred: 六
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred: 四
# pred: 四四
# pred: 六
# pred: 四七三
# pred:
# pred:
# pred: 四四
# pred:
# pred: 三
# pred: 三三
# pred: 四
# pred: 四
# pred: 三三三
# pred:
# pred: 六四四
# pred: 四
# pred: 一三
# pred:
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred: 四
# pred: 四四四三
# pred: 一
# pred:
# pred: 三
# pred:
# pred: 四四
# pred: 三四
# pred:
# pred: 四三
# pred:
# pred: 四七
# pred: 一一
# pred: 四三三三三
# pred: 四四四七
# pred:
# pred: 四
# pred:
# pred:
# pred: 四六
# pred: 六
# >>>> Accuracy: 0.0
# >> Train: [4][1/2]	Time 5.549 (5.549)	Data 0.230 (0.230)	Loss 8.8995 (8.8995)
# >> Train: [4][2/2]	Time 2.889 (4.219)	Data 0.001 (0.115)	Loss 8.9458 (8.9227)
# pred: 四
# pred: 三四
# pred:
# pred: 一
# pred: 四
# pred:
# pred: 四三六
# pred: 四
# pred:
# pred:
# pred: 四四四一三
# pred: 四六
# pred: 四
# pred: 四四
# pred:
# pred: 一
# pred: 四四
# pred: 三四
# pred: 三
# pred: 一
# pred:
# pred: 三
# pred: 四
# pred:
# pred: 七
# pred: 三六
# pred:
# pred:
# pred: 六
# pred:
# pred:
# pred: 四
# pred: 二
# pred: 三三三
# pred: 四
# pred:
# pred: 四
# pred: 四三六
# pred: 四
# pred: 四六
# pred: 四
# pred: 四三二
# pred: 三四
# pred: 四
# pred: 四
# pred: 四四四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred: 六
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred:
# pred: 四四
# pred: 六
# pred: 四七三
# pred:
# pred:
# pred: 四
# pred:
# pred: 三
# pred: 三三
# pred:
# pred: 四
# pred: 三三三
# pred:
# pred: 六四四
# pred: 四
# pred: 一三
# pred:
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred: 四
# pred: 四四四三
# pred: 一
# pred:
# pred: 三
# pred:
# pred: 四一
# pred: 三四
# pred:
# pred: 四三
# pred:
# pred: 四七
# pred: 一一
# pred: 四三三三三
# pred: 四四四七
# pred:
# pred: 四
# pred:
# pred:
# pred: 四六
# pred: 六
# >>>> Accuracy: 0.0
# >> Train: [5][1/2]	Time 5.645 (5.645)	Data 0.203 (0.203)	Loss 8.9074 (8.9074)
# >> Train: [5][2/2]	Time 3.028 (4.336)	Data 0.001 (0.102)	Loss 8.9187 (8.9131)
# pred: 四
# pred: 三四
# pred:
# pred: 一
# pred: 四
# pred:
# pred: 四三六
# pred: 四
# pred:
# pred:
# pred: 四四四一三
# pred: 四六
# pred: 四
# pred: 四四
# pred:
# pred: 一
# pred: 四四
# pred: 三四
# pred: 三
# pred:
# pred:
# pred: 三
# pred: 四
# pred:
# pred: 七
# pred: 三六
# pred:
# pred:
# pred: 六
# pred:
# pred:
# pred: 四
# pred:
# pred: 三三三
# pred: 四
# pred:
# pred: 四
# pred: 四三
# pred: 四
# pred: 四六
# pred: 四
# pred: 四三二
# pred: 三四
# pred: 四
# pred:
# pred: 四四四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred:
# pred: 四
# pred: 四
# pred:
# pred: 四
# pred:
# pred: 四四
# pred: 六
# pred: 四七三
# pred:
# pred:
# pred: 四
# pred:
# pred: 三
# pred: 三
# pred:
# pred: 四
# pred: 三三三
# pred:
# pred: 六四四
# pred: 四
# pred: 一三
# pred:
# pred: 四
# pred:
# pred:
# pred:
# pred:
# pred: 四
# pred: 四四三
# pred: 一
# pred:
# pred: 三
# pred:
# pred: 四四
# pred: 三
# pred:
# pred: 四三
# pred:
# pred: 四七
# pred: 一一
# pred: 四三三三
# pred: 四四四七
# pred:
# pred: 四
# pred:
# pred:
# pred: 四六
# pred: 六
# >>>> Accuracy: 0.0
# >> Train: [6][1/2]	Time 5.855 (5.855)	Data 0.268 (0.268)	Loss 8.9355 (8.9355)
# >> Train: [6][2/2]	Time 2.924 (4.389)	Data 0.001 (0.135)	Loss 8.8735 (8.9045)
# pred: 四
# pred: 四
# pred:
# pred:
# pred: 四
# pred:
# pred: 四三六
# pred: 四
# pred:
# pred:
# pred: 四四一三
# pred: 四六

# %%
torch.save(model.state_dict(), 'pretrained/new_prarams.pth')
