# %%
import os
import argparse
import time
import math
import random
import shutil
import contextlib
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.optim as optim
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence
import torch.utils.data as data
import torchvision.transforms as transforms

from utils.converter import LabelConverter, IndexConverter
from datasets.dataset import InMemoryDigitsDataset, DigitsDataset, collate_train, collate_dev, inmemory_train, inmemory_dev
from generate import gen_text_img

import models
from models.crnn import init_network
from models.densenet_ import DenseNet

import warnings
warnings.filterwarnings("always")


# from tensorboardX import SummaryWriter
# writer = SummaryWriter('./d9ata/runs')
model_names = sorted(name for name in models.__dict__
    if name.islower() and not name.startswith("__")
    and callable(models.__dict__[name]))
optimizer_names = ["sgd", "adam", "rmsprop"]

def parse_args():
    '''Parse input arguments.'''
    parser = argparse.ArgumentParser(description='Digit Recognition')
    parser.add_argument('--dataset-root', default='./data',
                        help='train dataset path')
    parser.add_argument('--arch', default='mobilenetv2_cifar', choices=model_names,
                        help='model architecture: {} (default: mobilenetv2_cifar)'.format(' | '.join(model_names)))
    parser.add_argument('--gpu-id', type=int, default=-1,
                        help='gpu called when train')
    parser.add_argument('--alphabet', default='0123456789',
                        help='label alphabet, string format or file')
    parser.add_argument('--optimizer', default='rmsprop', choices=optimizer_names,
                        help='optimizer options: {} (default: rmsprop)'.format(' | '.join(optimizer_names)))
    parser.add_argument('--max-epoch', type=int, default='30',
                        help='number of total epochs to run (default: 30)')
    parser.add_argument('--not-pretrained', dest='pretrained', action='store_false',
                        help='initialize model with random weights (default: pretrained on cifar10)')
    parser.add_argument('--validate-interval', type=int, default=1,
                        help='Interval to be displayed')
    parser.add_argument('--save-interval', type=int, default=1,
                        help='save a model')
    parser.add_argument('--workers', default=4, type=int,
                        help='number of data loading workers (default: 4)')
    parser.add_argument('--batch-size', type=int, default=64,
                        help='batch size to train a model')
    parser.add_argument('--train-samples', default=640000, type=int,
                        help='train sample number')
    parser.add_argument('--image-size', type=int, default=32,
                        help='maximum size of longer image side used for training (default: 32)')
    parser.add_argument('--lr', type=float, default=1e-3,
                        help='initial learning rate (default: 1e-3)')
    parser.add_argument('--decay-rate', type=float, default=0.1,
                        help='learning rate decay')
    parser.add_argument('--momentum', type=float, default=0.9,
                        help='momentum')
    parser.add_argument('--weight-decay', type=float, default=5e-4,
                        help='weight decay (default: 5e-4)')
    parser.add_argument('--print-freq', type=int, default=10,
                        help='print frequency (default: 10)')
    parser.add_argument('--directory', metavar='EXPORT_DIR', default='./checkpoint',
                        help='Where to store samples and models')
    parser.add_argument('--rnn', action='store_true',
                        help='Train the model with model of rnn')
    parser.add_argument('--resume', default='', type=str, metavar='FILENAME',
                        help='name of the latest checkpoint (default: None)')
    parser.add_argument('--test-only', action='store_true',
                        help='test only')
    args = parser.parse_args()
    return args

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()

    # switch to train mode
    model.train()

    end = time.time()

    for i, sample in enumerate(train_loader):
        # Measure data loading time
        data_time.update(time.time() - end)

        # Zero out gradients so we can accumulate new ones over batches
        optimizer.zero_grad()

        # step 2. Get our inputs targets ready for the network.
        # targets is a list of `torch.IntTensor` with `batch_size` size.
        target_lengths = sample.target_lengths.to(device)
        targets = sample.targets # Expected targets to have CPU Backend

        # step 3. Run out forward pass.
        images = sample.images
        unfixed = 1
        if unfixed:
            targets = targets.to(device)
            log_probs = []
            for image in images:
                image = image.unsqueeze(0).to(device)
                log_prob = model(image).squeeze(1)
                log_probs.append(log_prob)
            input_lengths = torch.IntTensor([i.size(0) for i in log_probs]).to(device)
            log_probs = pad_sequence(log_probs)
        else: # Batch
            images = images.to(device)
            log_probs = model(images)
            #log_probs = pad_sequence(log_probs)
            input_lengths = torch.full((images.size(0),), log_probs.size(0), dtype=torch.int32, device=device)

        # step 4. Compute the loss, gradients, and update the parameters
        # by calling optimizer.step()
        loss = criterion(log_probs, targets, input_lengths, target_lengths)
        losses.update(loss.item())
        loss.backward()

        # do one step for multiple batches
        # accumulated gradients are used
        optimizer.step()

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if (i+1) % args.print_freq == 0 or i == 0 or (i+1) == len(train_loader):
            print('>> Train: [{0}][{1}/{2}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Data {data_time.val:.3f} ({data_time.avg:.3f})\t'
                  'Loss {loss.val:.4f} ({loss.avg:.4f})'.format(
                   epoch+1, i+1, len(train_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses))

    return losses.avg

# %%
def validate(dev_loader, model, epoch, converter):
    batch_time = AverageMeter()
    accuracy = AverageMeter()

    # switch to evaluate mode
    model.eval()

    num_correct = 0
    num_verified = 0
    end = time.time()

    #for i, (images, targets) in enumerate(dev_loader):
    for i, sample in enumerate(dev_loader):
        images = sample.images
        targets = sample.targets
        print(targets)
        unfixed = 1
        if unfixed:
            preds = []
            for image in images:
                image = image.unsqueeze(0).to(device)
                log_prob = model(image)
                preds.append(converter.best_path_decode(log_prob, strings=False))
        else: # Batch
            images = images.to(device)
            log_probs = model(images)
            preds = converter.best_path_decode(log_probs, strings=False)

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        num_verified += len(targets)
        for pred, target in zip(preds, targets):
            print('pred:',pred)
            print('target:',target)
            if pred == target:
                num_correct += 1
        accuracy.update(num_correct / num_verified)

        if (i+1) % args.print_freq == 0 or i == 0 or (i+1) == len(dev_loader):
            print('>> Val: [{0}][{1}/{2}]\t'
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                  'Accu {accuracy.val:.3f}'.format(
                   epoch+1, i+1, len(dev_loader), batch_time=batch_time, accuracy=accuracy))

    return accuracy.val

# %%
def save_checkpoint(state, is_best, directory):
    filename = os.path.join(directory, '{}_epoch_{}.pth.tar'.format(state['arch'], state['epoch']))
    with contextlib.suppress(FileNotFoundError):
        os.remove(filename)
    torch.save(state, filename)
    if is_best:
        print('>>>> save best model at epoch: {}'.format(state['epoch']))
        filename_best = os.path.join(directory, '{}_best.pth.tar'.format(state['arch']))
        with contextlib.suppress(FileNotFoundError):
            os.remove(filename_best)
        shutil.copyfile(filename, filename_best)


class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def set_batchnorm_eval(m):
    classname = m.__class__.__name__
    if classname.find('BatchNorm') != -1:
        # freeze running mean and std:
        # we do training one image at a time
        # so the statistics would not be per batch
        # hence we choose freezing (ie using imagenet statistics)
        m.eval()
        # # freeze parameters:
        # # in fact no need to freeze scale and bias
        # # they can be learned
        # # that is why next two lines are commented
        # for p in m.parameters():
            # p.requires_grad = False

# %%
import sys
# alphabet/alphabet_decode_5990.txt
sys.argv = ['main.py','--dataset-root','alphabet','--arch','densenet121','--alphabet','alphabet/alphabet_decode_5990.txt',
            '--lr','5e-5','--max-epoch','100','--optimizer','rmsprop','--gpu-id','-1','--resume','densenet121_pretrained.pth.tar']

# %%
global args, device

args = parse_args()

if args.gpu_id < 0:
    device = torch.device("cpu")
else:
    os.environ["CUDA_VISIBLE_DEVICES"] = str(args.gpu_id)
    device = torch.device("cuda")
    torch.backends.cudnn.benchmark = True

# create export dir if it doesnt exist
directory = "{}".format(args.arch)
directory += "_{}_lr{:.1e}_wd{:.1e}".format(args.optimizer, args.lr, args.weight_decay)
directory += "_bsize{}_imsize{}".format(args.batch_size, args.image_size)

args.directory = os.path.join(args.directory, directory)
print(">> Creating directory if it does not exist:\n>> '{}'".format(args.directory))
if not os.path.exists(args.directory):
    os.makedirs(args.directory)

# initialize model
if args.pretrained:
    print(">> Using pre-trained model '{}'".format(args.arch))
else:
    print(">> Using model from scratch (random weights) '{}'".format(args.arch))

# load alphabet from file
if os.path.isfile(args.alphabet):
    alphabet = ''
    with open(args.alphabet, mode='r', encoding='utf-8') as f:
        for line in f.readlines():
            alphabet += line.strip()
    args.alphabet = alphabet

model_params = {}
model_params['architecture'] = args.arch
model_params['num_classes'] = len(args.alphabet) + 1
model_params['mean'] = (0.5,)
model_params['std'] = (0.5,)
model_params['pretrained'] = args.pretrained
model = init_network(model_params)
model = model.to(device)

model_path = 'pretrained/densenet121_pretrained.pth'
checkpoint = torch.load(model_path,map_location = 'cpu')

model.load_state_dict(checkpoint)

# model = DenseNet(img_height=32, drop_rate=0.2, num_classes=len(args.alphabet) + 1)

transform = transforms.Compose([
#     transforms.Resize((32, 280)),
    transforms.ToTensor(),
])
# Out:
# >> Creating directory if it does not exist:
# >> './checkpoint/densenet121_rmsprop_lr5.0e-05_wd5.0e-04_bsize64_imsize32'
# >> Using pre-trained model 'densenet121'

# %%
from datasets.dataset import InMemoryDigitsDataset, DigitsDataset, collate_train, collate_dev, inmemory_train, inmemory_dev

num = 10
dev_num = int(num/5)
use_file = 1
text_length = -1
font_size = 0
font_id = 1
space_width = 1
text_color = '#282828'
thread_count = 8

random_skew = False
skew_angle = 0
random_blur = False
blur = 0

distorsion = 0
background = 1

# for i in range(100):
#     img, label = train_dataset.__getitem__(i)
#     print(img.shape,label)
# plt.imshow(train_dataset.__getitem__(0)[0][0])

# %%
criterion = nn.CTCLoss()
# criterion = nn.CTCLoss(zero_infinity=True)
criterion = criterion.to(device)
# define optimizer
if args.optimizer == 'sgd':
    optimizer = optim.SGD(model.parameters(), lr=args.lr, momentum=args.momentum, weight_decay=args.weight_decay)
elif args.optimizer == 'rmsprop':
    optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)
elif args.optimizer == 'adam':
    optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.weight_decay)

converter = LabelConverter(args.alphabet, ignore_case=False)

# define learning rate decay schedule
# TODO: maybe pass as argument in future implementation?
exp_decay = math.exp(-0.1)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=exp_decay)
# step_decay = 1
# gamma_decay = 0.5
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=step_decay, gamma=gamma_decay)

is_best = False
best_accuracy = 0.0
accuracy = 0.0
start_epoch = 0

for epoch in range(start_epoch, args.max_epoch):
    text_meta, text_img = gen_text_img(num, use_file, text_length, font_size, font_id, space_width, background, text_color,
                          blur, random_blur, distorsion, skew_angle, random_skew, thread_count)
    dev_meta, dev_img = gen_text_img(dev_num, use_file, text_length, font_size, font_id, space_width, background, text_color,
                          blur, random_blur, distorsion, skew_angle, random_skew, thread_count)

    index_converter = IndexConverter(args.alphabet, ignore_case=False)

    train_dataset = InMemoryDigitsDataset(mode='train',text=text_meta,img=text_img,total=num,
                                      transform=transform, converter = index_converter)
    dev_dataset = InMemoryDigitsDataset(mode='dev', text=dev_meta, img=dev_img, total=dev_num,
                                    transform=transform, converter = index_converter)

    train_loader = data.DataLoader(train_dataset, batch_size=num, collate_fn=inmemory_train,
                               shuffle=True, num_workers=args.workers, pin_memory=True)
    dev_loader = data.DataLoader(dev_dataset, batch_size=dev_num, collate_fn=inmemory_dev,
                             shuffle=False, num_workers=args.workers, pin_memory=True)
    
    # aujust learning rate for each epoch
    scheduler.step()

    # train for one epoch on train set
    loss = train(train_loader, model, criterion, optimizer, epoch)

    # evaluate on validation set
    if (epoch + 1) % args.validate_interval == 0:
        with torch.no_grad():
            accuracy = validate(dev_loader, model, epoch, converter)

    # # evaluate on test datasets every test_freq epochs
    # if (epoch + 1) % args.test_freq == 0:
    #     with torch.no_grad():
    #         test(args.test_datasets, model)

    # remember best accuracy and save checkpoint
    is_best = accuracy > 0.0 and accuracy >= best_accuracy
    best_accuracy = max(accuracy, best_accuracy)

    if (epoch + 1) % args.save_interval == 0:
        save_checkpoint({
            'arch': args.arch,
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'best_accuracy': best_accuracy,
            'optimizer' : optimizer.state_dict(),
        }, is_best, args.directory)
# Out:
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 24])
# >> Train: [1][1/1]	Time 3.546 (3.546)	Data 0.059 (0.059)	Loss 0.5133 (0.5133)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 29])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# >> Val: [1][1/1]	Time 0.583 (0.583)	Accu 1.000
# >>>> save best model at epoch: 1
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 11])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 22])
# >> Train: [2][1/1]	Time 5.396 (5.396)	Data 0.147 (0.147)	Loss 0.1331 (0.1331)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 31])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [2][1/1]	Time 0.623 (0.623)	Accu 1.000
# >>>> save best model at epoch: 2
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 31])
# >> Train: [3][1/1]	Time 5.614 (5.614)	Data 0.159 (0.159)	Loss 0.0451 (0.0451)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 35])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [3][1/1]	Time 0.631 (0.631)	Accu 1.000
# >>>> save best model at epoch: 3
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 18])
# >> Train: [4][1/1]	Time 5.677 (5.677)	Data 0.178 (0.178)	Loss 0.0301 (0.0301)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 25])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [4][1/1]	Time 0.579 (0.579)	Accu 0.500
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 17])
# >> Train: [5][1/1]	Time 5.118 (5.118)	Data 0.195 (0.195)	Loss 0.0518 (0.0518)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 22])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [5][1/1]	Time 0.595 (0.595)	Accu 1.000
# >>>> save best model at epoch: 5
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 31])
# >> Train: [6][1/1]	Time 5.611 (5.611)	Data 0.175 (0.175)	Loss 0.0349 (0.0349)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 34])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [6][1/1]	Time 0.647 (0.647)	Accu 1.000
# >>>> save best model at epoch: 6
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 22])
# >> Train: [7][1/1]	Time 5.578 (5.578)	Data 0.168 (0.168)	Loss 0.0223 (0.0223)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [7][1/1]	Time 0.609 (0.609)	Accu 1.000
# >>>> save best model at epoch: 7
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 34])
# >> Train: [8][1/1]	Time 6.512 (6.512)	Data 0.173 (0.173)	Loss 0.0555 (0.0555)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 26])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [8][1/1]	Time 0.691 (0.691)	Accu 1.000
# >>>> save best model at epoch: 8
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 26])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 30])
# >> Train: [9][1/1]	Time 5.411 (5.411)	Data 0.175 (0.175)	Loss 0.0675 (0.0675)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [9][1/1]	Time 0.687 (0.687)	Accu 1.000
# >>>> save best model at epoch: 9
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 28])
# >> Train: [10][1/1]	Time 5.805 (5.805)	Data 0.171 (0.171)	Loss 0.0217 (0.0217)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 33])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [10][1/1]	Time 0.609 (0.609)	Accu 1.000
# >>>> save best model at epoch: 10
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 24])
# >> Train: [11][1/1]	Time 5.052 (5.052)	Data 0.171 (0.171)	Loss 0.0402 (0.0402)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 33])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [11][1/1]	Time 0.747 (0.747)	Accu 1.000
# >>>> save best model at epoch: 11
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 24])
# >> Train: [12][1/1]	Time 5.178 (5.178)	Data 0.172 (0.172)	Loss 0.0285 (0.0285)
# [[352, 569, 1253, 965, 1, 1174, 237, 440], [253, 352, 569, 1255, 382, 249]]
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 17])
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# >> Val: [12][1/1]	Time 0.591 (0.591)	Accu 1.000
# >>>> save best model at epoch: 12
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 29])
# >> Train: [13][1/1]	Time 4.930 (4.930)	Data 0.166 (0.166)	Loss 0.0284 (0.0284)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 32])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [13][1/1]	Time 0.645 (0.645)	Accu 1.000
# >>>> save best model at epoch: 13
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 27])
# >> Train: [14][1/1]	Time 5.336 (5.336)	Data 0.171 (0.171)	Loss 0.0242 (0.0242)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 24])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [14][1/1]	Time 0.544 (0.544)	Accu 1.000
# >>>> save best model at epoch: 14
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 17])
# >> Train: [15][1/1]	Time 5.575 (5.575)	Data 0.178 (0.178)	Loss 0.0371 (0.0371)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 23])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [15][1/1]	Time 0.622 (0.622)	Accu 1.000
# >>>> save best model at epoch: 15
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 18])
# >> Train: [16][1/1]	Time 5.904 (5.904)	Data 0.191 (0.191)	Loss 0.0246 (0.0246)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 28])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# >> Val: [16][1/1]	Time 0.686 (0.686)	Accu 1.000
# >>>> save best model at epoch: 16
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 32])
# >> Train: [17][1/1]	Time 5.679 (5.679)	Data 0.166 (0.166)	Loss 0.0226 (0.0226)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 25])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [17][1/1]	Time 0.602 (0.602)	Accu 1.000
# >>>> save best model at epoch: 17
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 26])
# torch.Size([1, 384, 4, 28])
# >> Train: [18][1/1]	Time 5.245 (5.245)	Data 0.169 (0.169)	Loss 0.0243 (0.0243)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 36])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [18][1/1]	Time 0.718 (0.718)	Accu 1.000
# >>>> save best model at epoch: 18
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 12])
# >> Train: [19][1/1]	Time 5.114 (5.114)	Data 0.174 (0.174)	Loss 0.0397 (0.0397)
# [[352, 569, 1253, 965, 1, 1174, 237, 440], [253, 352, 569, 1255, 382, 249]]
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 17])
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# >> Val: [19][1/1]	Time 0.606 (0.606)	Accu 1.000
# >>>> save best model at epoch: 19
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 12])
# >> Train: [20][1/1]	Time 5.111 (5.111)	Data 0.165 (0.165)	Loss 0.0298 (0.0298)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 33])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [20][1/1]	Time 0.653 (0.653)	Accu 1.000
# >>>> save best model at epoch: 20
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 17])
# >> Train: [21][1/1]	Time 5.030 (5.030)	Data 0.172 (0.172)	Loss 0.0154 (0.0154)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 35])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [21][1/1]	Time 0.703 (0.703)	Accu 1.000
# >>>> save best model at epoch: 21
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 29])
# >> Train: [22][1/1]	Time 5.264 (5.264)	Data 0.163 (0.163)	Loss 0.0318 (0.0318)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 33])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [22][1/1]	Time 0.662 (0.662)	Accu 1.000
# >>>> save best model at epoch: 22
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 26])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 31])
# >> Train: [23][1/1]	Time 5.136 (5.136)	Data 0.171 (0.171)	Loss 0.0401 (0.0401)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 25])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [23][1/1]	Time 0.618 (0.618)	Accu 1.000
# >>>> save best model at epoch: 23
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 33])
# >> Train: [24][1/1]	Time 5.535 (5.535)	Data 0.174 (0.174)	Loss 0.0339 (0.0339)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [24][1/1]	Time 0.804 (0.804)	Accu 1.000
# >>>> save best model at epoch: 24
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 11])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 23])
# >> Train: [25][1/1]	Time 5.926 (5.926)	Data 0.179 (0.179)	Loss 0.0261 (0.0261)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 28])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# >> Val: [25][1/1]	Time 0.694 (0.694)	Accu 1.000
# >>>> save best model at epoch: 25
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 28])
# >> Train: [26][1/1]	Time 5.990 (5.990)	Data 0.182 (0.182)	Loss 0.0161 (0.0161)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# >> Val: [26][1/1]	Time 0.721 (0.721)	Accu 1.000
# >>>> save best model at epoch: 26
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 23])
# >> Train: [27][1/1]	Time 4.795 (4.795)	Data 0.174 (0.174)	Loss 0.0177 (0.0177)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 36])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [27][1/1]	Time 0.802 (0.802)	Accu 1.000
# >>>> save best model at epoch: 27
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 28])
# >> Train: [28][1/1]	Time 4.908 (4.908)	Data 0.182 (0.182)	Loss 0.0255 (0.0255)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 31])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [28][1/1]	Time 0.690 (0.690)	Accu 1.000
# >>>> save best model at epoch: 28
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 30])
# >> Train: [29][1/1]	Time 5.714 (5.714)	Data 0.180 (0.180)	Loss 0.0189 (0.0189)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 22])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [29][1/1]	Time 0.693 (0.693)	Accu 1.000
# >>>> save best model at epoch: 29
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 24])
# >> Train: [30][1/1]	Time 5.247 (5.247)	Data 0.174 (0.174)	Loss 0.0551 (0.0551)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 33])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [30][1/1]	Time 0.686 (0.686)	Accu 1.000
# >>>> save best model at epoch: 30
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 11])
# torch.Size([1, 384, 4, 26])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 17])
# >> Train: [31][1/1]	Time 5.298 (5.298)	Data 0.179 (0.179)	Loss 0.0319 (0.0319)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [31][1/1]	Time 0.785 (0.785)	Accu 1.000
# >>>> save best model at epoch: 31
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 25])
# >> Train: [32][1/1]	Time 6.242 (6.242)	Data 0.184 (0.184)	Loss 0.0167 (0.0167)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [32][1/1]	Time 0.759 (0.759)	Accu 1.000
# >>>> save best model at epoch: 32
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 11])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 22])
# >> Train: [33][1/1]	Time 5.064 (5.064)	Data 0.186 (0.186)	Loss 0.0306 (0.0306)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 29])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352]
# >> Val: [33][1/1]	Time 0.715 (0.715)	Accu 1.000
# >>>> save best model at epoch: 33
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 30])
# >> Train: [34][1/1]	Time 6.164 (6.164)	Data 0.184 (0.184)	Loss 0.0177 (0.0177)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 31])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [34][1/1]	Time 0.723 (0.723)	Accu 1.000
# >>>> save best model at epoch: 34
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 33])
# >> Train: [35][1/1]	Time 5.380 (5.380)	Data 0.178 (0.178)	Loss 0.0184 (0.0184)
# [[352, 569, 1253, 965, 1, 1174, 237, 440], [253, 352, 569, 1255, 382, 249]]
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 18])
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# >> Val: [35][1/1]	Time 0.700 (0.700)	Accu 1.000
# >>>> save best model at epoch: 35
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 12])
# >> Train: [36][1/1]	Time 6.152 (6.152)	Data 0.188 (0.188)	Loss 0.0208 (0.0208)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 26])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [36][1/1]	Time 0.730 (0.730)	Accu 1.000
# >>>> save best model at epoch: 36
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 11])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 17])
# >> Train: [37][1/1]	Time 6.137 (6.137)	Data 0.197 (0.197)	Loss 0.0358 (0.0358)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 22])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [37][1/1]	Time 0.651 (0.651)	Accu 1.000
# >>>> save best model at epoch: 37
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 26])
# >> Train: [38][1/1]	Time 7.611 (7.611)	Data 0.318 (0.318)	Loss 0.0169 (0.0169)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 27])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [38][1/1]	Time 1.129 (1.129)	Accu 1.000
# >>>> save best model at epoch: 38
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 17])
# >> Train: [39][1/1]	Time 5.115 (5.115)	Data 0.195 (0.195)	Loss 0.0340 (0.0340)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 25])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [39][1/1]	Time 0.620 (0.620)	Accu 1.000
# >>>> save best model at epoch: 39
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 22])
# >> Train: [40][1/1]	Time 9.584 (9.584)	Data 0.183 (0.183)	Loss 0.0196 (0.0196)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 25])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868]
# >> Val: [40][1/1]	Time 0.665 (0.665)	Accu 1.000
# >>>> save best model at epoch: 40
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 33])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 23])
# >> Train: [41][1/1]	Time 5.649 (5.649)	Data 0.172 (0.172)	Loss 0.0376 (0.0376)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [41][1/1]	Time 0.739 (0.739)	Accu 1.000
# >>>> save best model at epoch: 41
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 22])
# >> Train: [42][1/1]	Time 4.683 (4.683)	Data 0.177 (0.177)	Loss 0.0206 (0.0206)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 32])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [42][1/1]	Time 0.766 (0.766)	Accu 1.000
# >>>> save best model at epoch: 42
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 24])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 28])
# >> Train: [43][1/1]	Time 5.339 (5.339)	Data 0.187 (0.187)	Loss 0.0326 (0.0326)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 23])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [43][1/1]	Time 0.603 (0.603)	Accu 1.000
# >>>> save best model at epoch: 43
# torch.Size([1, 384, 4, 31])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 34])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 30])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 36])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 36])
# >> Train: [44][1/1]	Time 5.517 (5.517)	Data 0.190 (0.190)	Loss 0.0227 (0.0227)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 24])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440]
# >> Val: [44][1/1]	Time 0.678 (0.678)	Accu 1.000
# >>>> save best model at epoch: 44
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 29])
# torch.Size([1, 384, 4, 26])
# torch.Size([1, 384, 4, 26])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 21])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 22])
# torch.Size([1, 384, 4, 18])
# >> Train: [45][1/1]	Time 6.029 (6.029)	Data 0.179 (0.179)	Loss 0.0356 (0.0356)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 35])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569, 28]
# >> Val: [45][1/1]	Time 0.841 (0.841)	Accu 1.000
# >>>> save best model at epoch: 45
# torch.Size([1, 384, 4, 20])
# torch.Size([1, 384, 4, 35])
# torch.Size([1, 384, 4, 32])
# torch.Size([1, 384, 4, 28])
# torch.Size([1, 384, 4, 18])
# torch.Size([1, 384, 4, 25])
# torch.Size([1, 384, 4, 23])
# torch.Size([1, 384, 4, 12])
# torch.Size([1, 384, 4, 27])
# torch.Size([1, 384, 4, 22])
# >> Train: [46][1/1]	Time 5.600 (5.600)	Data 0.268 (0.268)	Loss 0.0330 (0.0330)
# [[253, 352, 569, 1255, 382, 249], [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]]
# torch.Size([1, 384, 4, 17])
# torch.Size([1, 384, 4, 30])
# pred: [253, 352, 569, 1255, 382, 249]
# target: [253, 352, 569, 1255, 382, 249]
# pred: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# target: [352, 569, 1253, 965, 1, 1174, 237, 440, 868, 352, 569]
# >> Val: [46][1/1]	Time 0.681 (0.681)	Accu 1.000
# >>>> save best model at epoch: 46
# Process ForkPoolWorker-1113:
# Process ForkPoolWorker-1115:
# Process ForkPoolWorker-1116:
# Process ForkPoolWorker-1114:
# Process ForkPoolWorker-1117:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/opt/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/opt/conda/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/opt/conda/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/opt/conda/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/opt/conda/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-434b64fc8b17> in <module>()
#      29                           blur, random_blur, distorsion, skew_angle, random_skew, thread_count)
#      30     dev_meta, dev_img = gen_text_img(dev_num, use_file, text_length, font_size, font_id, space_width, background, text_color,
# ---> 31                           blur, random_blur, distorsion, skew_angle, random_skew, thread_count)
#      32
#      33     index_converter = IndexConverter(args.alphabet, ignore_case=False)
#
# ~/TextRecognitionDataGenerator/generate.py in gen_text_img(num, use_file, text_length, font_size, font_id, space_width, background, text_color, blur, random_blur, distorsion, skew_angle, random_skew, thread_count)
#     106         strings = create_strings_from_dict(text_length, num, lang_dict)
#     107
# --> 108     p = Pool(thread_count)
#     109     mutex = threading.Lock()
#     110     result = []
#
# /opt/conda/lib/python3.6/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117         from .pool import Pool
#     118         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 119                     context=self.get_context())
#     120
#     121     def RawValue(self, typecode_or_type, *args):
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     172         self._processes = processes
#     173         self._pool = []
# --> 174         self._repopulate_pool()
#     175
#     176         self._worker_handler = threading.Thread(
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in _repopulate_pool(self)
#     237             w.name = w.name.replace('Process', 'PoolWorker')
#     238             w.daemon = True
# --> 239             w.start()
#     240             util.debug('added worker')
#     241
#
# /opt/conda/lib/python3.6/multiprocessing/process.py in start(self)
#     103                'daemonic processes are not allowed to have children'
#     104         _cleanup()
# --> 105         self._popen = self._Popen(self)
#     106         self._sentinel = self._popen.sentinel
#     107         # Avoid a refcycle if the target function holds an indirect
#
# /opt/conda/lib/python3.6/multiprocessing/context.py in _Popen(process_obj)
#     275         def _Popen(process_obj):
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#     279     class SpawnProcess(process.BaseProcess):
#
# /opt/conda/lib/python3.6/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      18         sys.stderr.flush()
#      19         self.returncode = None
# ---> 20         self._launch(process_obj)
#      21
#      22     def duplicate_for_child(self, fd):
#
# /opt/conda/lib/python3.6/multiprocessing/popen_fork.py in _launch(self, process_obj)
#      65         code = 1
#      66         parent_r, child_w = os.pipe()
# ---> 67         self.pid = os.fork()
#      68         if self.pid == 0:
#      69             try:
#
# KeyboardInterrupt:
